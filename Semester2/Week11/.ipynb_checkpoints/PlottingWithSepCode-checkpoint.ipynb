# %%
import physplot as phys
import numpy as np
from __future__ import division

array1 = np.array([1.,2.,3.,4.])
array2 = np.array([5.5,6.1231,7.4542,8.9992])
errarray2 = np.array([.5,.5,.5,.5])

#plotfit takes in parameters in this order
#phys.plotfit(x,y,dy,title,'xlabel(units)','ylabel(units)','slope units')  Slope units will not render in LaTeX

phys.plotfit(array1,array2,errarray2,'Sample Plot','xaxis($m^2$)','yaxis(s)','s/m^2')
# Out:
# Slope =  1.18287   s/m^2
# Error in slope =  0.22360679775   s/m^2
# Goodness of fit =  0.898726572
